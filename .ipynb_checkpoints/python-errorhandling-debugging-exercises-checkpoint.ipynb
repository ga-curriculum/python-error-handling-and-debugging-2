# %% [markdown]
# <img src="./assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Python Error Handling and Debugging
#
# ---

# %% [markdown]
# ### About
# Practice identifying and fixing common errors in Python code, along with creating programs that can anticipate specific error types.
#
# ### Learning Objectives
# - Identify common errors in Python.
# - Read error messages for guidance to fix errors.
# - Implement `try`/`except` error handling.
#
#
# ### Notebook Guide
# - Introduction to Error Handling and Debugging
# - Now You Try
#     - Exercise 1: Identify the Error
#     - Exercise 2: Fix the Bugs
#     - Exercise 3: Implementing Error Handling
#     - Exercise 4: Advanced Error Handling
#     - Challenge: Build a Robust File Processing System

# %% [markdown]
# # Introduction to Error Handling and Debugging
#
# Errors are an inevitable part of programming. Being able to understand, anticipate, and handle errors effectively is an essential skill for any Python developer. This notebook will help you learn how to:
#
# - Identify common types of errors in Python
# - Read and interpret error messages
# - Handle errors gracefully using try/except blocks
# - Debug your code effectively
#
# ### Types of Python Errors
#
# Python errors generally fall into two categories:
#
# 1. **Syntax Errors**: These occur when Python can't understand your code due to incorrect syntax (like forgetting a colon, mismatched parentheses, etc.). Python detects these before your code runs.
#
# 2. **Exceptions**: These occur during execution when something unexpected happens (like trying to divide by zero, accessing a non-existent file, etc.). Python provides many built-in exception types to help identify what went wrong.
#
# ### Common Python Exceptions
#
# Here are some of the most common exceptions you'll encounter:
#
# - `SyntaxError`: Invalid Python syntax
# - `TypeError`: Operation applied to inappropriate type
# - `NameError`: Variable not defined
# - `IndexError`: Index out of range
# - `KeyError`: Key not found in dictionary
# - `ValueError`: Correct type but inappropriate value
# - `FileNotFoundError`: Trying to access a non-existent file
# - `ZeroDivisionError`: Dividing by zero
# - `ImportError`: Module could not be imported
# - `IndentationError`: Incorrect indentation
#
# ### Reading Error Messages
#
# Python error messages typically include:
# - The type of error (e.g., `TypeError`, `ValueError`)
# - A description of what went wrong
# - A traceback showing where in your code the error occurred
#
# Error messages are your friends! They provide valuable clues about what's wrong and where to look.
#
# ### Using Try/Except Blocks
#
# Python's `try`/`except` blocks allow you to handle potential errors gracefully:
#
# ```python
# try:
#     # Code that might cause an exception
#     result = 10 / 0
# except ZeroDivisionError:
#     # Code to execute if a ZeroDivisionError occurs
#     print("You can't divide by zero!")
# ```
#
# You can also catch multiple exceptions, use a generic `except` clause (though this is generally not recommended), and use the `finally` clause for code that should run regardless of whether an exception occurred.
#
# Let's dive into some exercises to practice these concepts!

# %% [markdown]
# ## Warmup: The Bug Hunter's Guild
#
# Welcome to the Bug Hunter's Guild! As a novice bug hunter, your first task is to identify the types of bugs (errors) you might encounter in the wild. Let's see if you can spot them!

# %%
# Let's create a "Bug Bestiary" - a dictionary of common Python errors
bug_bestiary = {
    'SyntaxError': 'The Python parser is having trouble understanding your code',
    'TypeError': 'An operation or function is applied to an object of inappropriate type',
    'NameError': 'A local or global name is not found',
    'IndexError': 'A sequence subscript is out of range',
    'KeyError': 'A dictionary key is not found',
    'ValueError': 'An operation or function receives an argument of correct type but inappropriate value',
    'FileNotFoundError': 'The requested file cannot be found',
    'ZeroDivisionError': 'Division or modulo by zero'
}

# Let's print our bug bestiary in a nice format
print("🐞 THE BUG HUNTER'S BESTIARY 🐞")
print("=============================\n")
for bug, description in bug_bestiary.items():
    print(f"Bug: {bug}")
    print(f"Description: {description}")
    print("-----------------------------")
# Out:
# 🐞 THE BUG HUNTER'S BESTIARY 🐞
# =============================
#
# Bug: SyntaxError
# Description: The Python parser is having trouble understanding your code
# -----------------------------
# Bug: TypeError
# Description: An operation or function is applied to an object of inappropriate type
# -----------------------------
# Bug: NameError
# Description: A local or global name is not found
# -----------------------------
# Bug: IndexError
# Description: A sequence subscript is out of range
# -----------------------------
# Bug: KeyError
# Description: A dictionary key is not found
# -----------------------------
# Bug: ValueError
# Description: An operation or function receives an argument of correct type but inappropriate value
# -----------------------------
# Bug: FileNotFoundError
# Description: The requested file cannot be found
# -----------------------------
# Bug: ZeroDivisionError
# Description: Division or modulo by zero
# -----------------------------

# %% [markdown]
# # Now You Try

# %% [markdown]
# ## Exercise 1: Identify the Error
#
# In this exercise, you'll analyze several code snippets with errors. Your task is to:
# 1. Run the code and observe the error
# 2. Identify the type of error
# 3. Explain what caused the error

# %%
# Error 1: Run this code and identify the error
greeting = "Hello, world!"
print(greting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Error 1: Run this code and identify the error
#       2 greeting = "Hello, world!"
# ----> 3 print(greting)
#
# NameError: name 'greting' is not defined

# %% [markdown]
# **Your Analysis:**
# - Error Type:
# - Cause:

# %%
# Error 2: Run this code and identify the error
numbers = [1, 2, 3, 4, 5]
sixth_number = numbers[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Error 2: Run this code and identify the error
#       2 numbers = [1, 2, 3, 4, 5]
# ----> 3 sixth_number = numbers[5]
#
# IndexError: list index out of range

# %% [markdown]
# **Your Analysis:**
# - Error Type:
# - Cause:

# %%
# Error 3: Run this code and identify the error
user_data = {'name': 'Alice', 'age': 30}
print(user_data['email'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Error 3: Run this code and identify the error
#       2 user_data = {'name': 'Alice', 'age': 30}
# ----> 3 print(user_data['email'])
#
# KeyError: 'email'

# %% [markdown]
# **Your Analysis:**
# - Error Type:
# - Cause:

# %%
# Error 4: Run this code and identify the error
result = 10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Error 4: Run this code and identify the error
# ----> 2 result = 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **Your Analysis:**
# - Error Type:
# - Cause:

# %%
# Error 5: Run this code and identify the error
value = int("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Error 5: Run this code and identify the error
# ----> 2 value = int("Hello")
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# **Your Analysis:**
# - Error Type:
# - Cause:

# %% [markdown]
# ## Exercise 2: Fix the Bugs
#
# Now that you can identify errors, let's practice fixing them. Your task is to correct the code in each cell below so it runs without errors.

# %%
# Bug 1: Fix this code
favourite_fruits = ['apple', 'banana', 'orange']
print("My favourite fruits are:")
for i in range(4):
    print(favourite_fruits[i])
# Out:
# My favourite fruits are:
# apple
# banana
# orange
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 5
#       3 print("My favourite fruits are:")
#       4 for i in range(4):
# ----> 5     print(favourite_fruits[i])
#
# IndexError: list index out of range

# %%
# Bug 2: Fix this code
def calculate_average(numbers):
    total = sum(numbers)
    average = total / len(numbers)
    return average

# Test with an empty list
result = calculate_average([])
print(f"The average is {result}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 8
#       5     return average
#       7 # Test with an empty list
# ----> 8 result = calculate_average([])
#       9 print(f"The average is {result}")
#
# Cell In[24], line 4, in calculate_average(numbers)
#       2 def calculate_average(numbers):
#       3     total = sum(numbers)
# ----> 4     average = total / len(numbers)
#       5     return average
#
# ZeroDivisionError: division by zero

# %%
# Bug 3: Fix this code
user_info = {'name': 'Bob', 'age': 25}

print(f"Name: {user_info['name']}")
print(f"Age: {user_info['age']}")
print(f"Email: {user_info['email']}")
# Out:
# Name: Bob
# Age: 25
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 6
#       4 print(f"Name: {user_info['name']}")
#       5 print(f"Age: {user_info['age']}")
# ----> 6 print(f"Email: {user_info['email']}")
#
# KeyError: 'email'

# %%
# Bug 4: Fix this code
file_path = 'non_existent_file.txt'
with open(file_path, 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Bug 4: Fix this code
#       2 file_path = 'non_existent_file.txt'
# ----> 3 with open(file_path, 'r') as file:
#       4     contents = file.read()
#       5     print(contents)
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %%
# Bug 5: Fix this code
def calculate_discount(price, discount_percentage):
    discount_amount = price * (discount_percentage / 100)
    final_price = price - discount_amount
    return final_price

# Try with invalid input
print(calculate_discount('fifty', 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       5     return final_price
#       7 # Try with invalid input
# ----> 8 print(calculate_discount('fifty', 10))
#
# Cell In[30], line 3, in calculate_discount(price, discount_percentage)
#       2 def calculate_discount(price, discount_percentage):
# ----> 3     discount_amount = price * (discount_percentage / 100)
#       4     final_price = price - discount_amount
#       5     return final_price
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ## Exercise 3: Implementing Error Handling
#
# Now let's practice implementing try/except blocks to handle errors gracefully. For each function below, add appropriate error handling.

# %%
# 3.1: Implement error handling for division
def safe_division(a, b):
    """Divide a by b and handle potential errors."""
    # TODO: Implement try/except to handle ZeroDivisionError
    # If b is zero, return None and print an error message
    # Otherwise, return the result of a / b
    
    result = a / b
    return result

# Test the function
print(safe_division(10, 2))  # Should return 5.0
print(safe_division(10, 0))  # Should handle error and return None
# Out:
# 5.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 13
#      11 # Test the function
#      12 print(safe_division(10, 2))  # Should return 5.0
# ---> 13 print(safe_division(10, 0))
#
# Cell In[33], line 8, in safe_division(a, b)
#       3 """Divide a by b and handle potential errors."""
#       4 # TODO: Implement try/except to handle ZeroDivisionError
#       5 # If b is zero, return None and print an error message
#       6 # Otherwise, return the result of a / b
# ----> 8 result = a / b
#       9 return result
#
# ZeroDivisionError: division by zero

# %%
# 3.2: Implement error handling for list operations
def get_element(lst, index):
    """Get an element from a list at the specified index with error handling."""
    # TODO: Implement try/except to handle IndexError
    # If the index is out of range, return None and print an error message
    # Otherwise, return the element at the specified index
    
    element = lst[index]
    return element

# Test the function
my_list = ['a', 'b', 'c']
print(get_element(my_list, 1))  # Should return 'b'
print(get_element(my_list, 5))  # Should handle error and return None
# Out:
# b
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 14
#      12 my_list = ['a', 'b', 'c']
#      13 print(get_element(my_list, 1))  # Should return 'b'
# ---> 14 print(get_element(my_list, 5))
#
# Cell In[35], line 8, in get_element(lst, index)
#       3 """Get an element from a list at the specified index with error handling."""
#       4 # TODO: Implement try/except to handle IndexError
#       5 # If the index is out of range, return None and print an error message
#       6 # Otherwise, return the element at the specified index
# ----> 8 element = lst[index]
#       9 return element
#
# IndexError: list index out of range

# %%
# 3.3: Implement error handling for file operations
def read_file_content(filename):
    """Read and return the content of a file with error handling."""
    # TODO: Implement try/except to handle FileNotFoundError and PermissionError
    # If the file doesn't exist or can't be accessed, return None and print an appropriate error message
    # Otherwise, return the file content as a string
    
    with open(filename, 'r') as file:
        content = file.read()
    return content

# Test the function
print(read_file_content('sample.txt'))  # Assuming this file doesn't exist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 13
#      10     return content
#      12 # Test the function
# ---> 13 print(read_file_content('sample.txt'))
#
# Cell In[37], line 8, in read_file_content(filename)
#       3 """Read and return the content of a file with error handling."""
#       4 # TODO: Implement try/except to handle FileNotFoundError and PermissionError
#       5 # If the file doesn't exist or can't be accessed, return None and print an appropriate error message
#       6 # Otherwise, return the file content as a string
# ----> 8 with open(filename, 'r') as file:
#       9     content = file.read()
#      10 return content
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
# 3.4: Implement error handling for type conversion
def parse_positive_integer(value):
    """Parse a string to a positive integer with error handling."""
    # TODO: Implement try/except to handle ValueError
    # If the value can't be converted to an integer, or if it's negative,
    # return None and print an appropriate error message
    # Otherwise, return the integer value
    
    number = int(value)
    if number < 0:
        raise ValueError("Number must be positive")
    return number

# Test the function
print(parse_positive_integer("42"))   # Should return 42
print(parse_positive_integer("abc"))  # Should handle error and return None
print(parse_positive_integer("-5"))   # Should handle error and return None
# Out:
# 42
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 16
#      14 # Test the function
#      15 print(parse_positive_integer("42"))   # Should return 42
# ---> 16 print(parse_positive_integer("abc"))  # Should handle error and return None
#      17 print(parse_positive_integer("-5"))
#
# Cell In[39], line 9, in parse_positive_integer(value)
#       3 """Parse a string to a positive integer with error handling."""
#       4 # TODO: Implement try/except to handle ValueError
#       5 # If the value can't be converted to an integer, or if it's negative,
#       6 # return None and print an appropriate error message
#       7 # Otherwise, return the integer value
# ----> 9 number = int(value)
#      10 if number < 0:
#      11     raise ValueError("Number must be positive")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ## Exercise 4: Advanced Error Handling
#
# Let's practice more complex error handling scenarios. In this exercise, you'll create functions that handle multiple types of exceptions and use finally blocks.

# %%
# 4.1: Create a calculator function with comprehensive error handling
def calculator(operation, a, b):
    """Calculate a result based on operation (add, subtract, multiply, divide).
    Handle all potential errors with appropriate messages."""
    # TODO: Implement try/except blocks to handle:
    # - TypeError if a or b aren't numbers
    # - ZeroDivisionError for division by zero
    # - ValueError if the operation isn't recognized
    # Make sure to return the result if everything is valid
    
    pass  # Replace this with your implementation

# Test the function
print(calculator('add', 5, 3))       # Should return 8
print(calculator('divide', 10, 2))   # Should return 5.0
print(calculator('divide', 10, 0))   # Should handle division by zero
print(calculator('multiply', 4, 'x')) # Should handle type error
print(calculator('power', 2, 3))     # Should handle invalid operation
# Out:
# None
# None
# None
# None
# None

# %%
# 4.2: Create a function to safely process a list of values
def process_values(values):
    """Process a list of values by doubling numbers and capitalizing strings.
    Skip non-string, non-number values, and return the processed list."""
    # TODO: Implement try/except blocks within a loop to handle each value
    # - For numbers (int/float), double the value
    # - For strings, capitalize the value
    # - Skip other types of values with a message
    # - Return the list of processed values
    
    pass  # Replace this with your implementation

# Test the function
mixed_values = [10, 'hello', 3.14, [1, 2], 'python', None, 42]
print(process_values(mixed_values))
# Out:
# None

# %% [markdown]
# ## Challenge: Build a Robust File Processing System
#
# For the final challenge, you'll build a complete file processing system that demonstrates comprehensive error handling, informative error messages, and graceful failure recovery.

# %%
def process_data_file(filename):
    """Process a data file with comprehensive error handling.
    
    The file should contain numbers, one per line.
    The function should:
    1. Safely open and read the file
    2. Parse each line to a number
    3. Calculate statistics (sum, average, min, max)
    4. Write the results to a new file called 'results.txt'
    5. Handle all potential errors appropriately
    
    Returns a dictionary with either the results or error information.
    """
    # TODO: Implement a complete solution with thorough error handling
    # using try/except/finally blocks as needed
    
    pass  # Replace this with your implementation

# Test with a good file (you can create this)
print("Testing with a good data file:")
# First, create a test file
with open('good_data.txt', 'w') as f:
    f.write("10\n20\n30\n40\n50")
print(process_data_file('good_data.txt'))

# Test with a file with some invalid data
print("\nTesting with bad data:")
with open('bad_data.txt', 'w') as f:
    f.write("10\nabc\n30\n\n40\nxyz")
print(process_data_file('bad_data.txt'))

# Test with a non-existent file
print("\nTesting with non-existent file:")
print(process_data_file('does_not_exist.txt'))
# Out:
# Testing with a good data file:
# None
#
# Testing with bad data:
# None
#
# Testing with non-existent file:
# None

# %% [markdown]
# ## Conclusion
#
# Congratulations on completing these exercises on error handling and debugging! You've practiced:
#
# - Identifying common Python errors
# - Reading and interpreting error messages
# - Fixing bugs in existing code
# - Implementing try/except blocks for various error scenarios
# - Creating robust programs that can handle unexpected situations
#
# These skills will be invaluable as you develop more complex Python applications. Remember, errors aren't a sign of failure—they're opportunities to make your code more robust and reliable!
